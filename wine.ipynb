# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_df=pd.read_csv('data/winequality-red.csv',sep=';')
red_df.to_csv('data/winequality-red2.csv',index=False)

# %%
white_df=pd.read_csv('data/winequality-white.csv',sep=';')
white_df.to_csv('data/winequality-white2.csv', index=False)

# %%
red_df.insert(0,column='type', value='red')
white_df.insert(0, column='type', value='white')
print(red_df.head())
print(white_df.head())
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
print(red_df.shape)
print(white_df.shape)
# Out:
# (1599, 13)
# (4898, 13)

# %%
wine=pd.concat([red_df, white_df])
print(wine.shape)
# Out:
# (6497, 13)

# %%
wine.to_csv('data/wine.csv', index=False)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB

# %%
wine.columns=wine.columns.str.replace(' ','_')
print(wine.head())
# Out:
#   type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
sorted(wine.quality.unique())
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
wine.quality.value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# 1. wine의 type별 quality의 요약을 구하라.
# 2. wine의 type별 quality의 평균을 구하라.
# 3. wine의 type별 quality의 평균과 표준편차를 구하라.
# 4. wine의 quality별 alcohol의 평균을 구하라.
# 5. wine의 quality별 alcohol과 pH의 평균과 합을 구하라.
# 6. wine의 type별 alcohol과 평균과 합을 quality의 평균과 표준편차를 구하라.
# 7. wine의 quality별 count를 사용하여 bar chart 그리기, 단 quality로 오름차순 정렬하여 그린다.

# %%
print(wine.groupby('type')['quality'].describe())
print(wine.groupby('quality')['alcohol'].describe())
# Out:
#         count      mean       std  min  25%  50%  75%  max
# type
# red    1599.0  5.636023  0.807569  3.0  5.0  6.0  6.0  8.0
# white  4898.0  5.877909  0.885639  3.0  5.0  6.0  6.0  9.0
#           count       mean       std   min     25%    50%   75%   max
# quality
# 3          30.0  10.215000  1.106497   8.0   9.625  10.15  11.0  12.6
# 4         216.0  10.180093  0.985923   8.4   9.400  10.00  10.9  13.5
# 5        2138.0   9.837783  0.814416   8.0   9.300   9.60  10.3  14.9
# 6        2836.0  10.587553  1.126491   8.4   9.600  10.50  11.4  14.0
# 7        1079.0  11.386006  1.199337   8.6  10.625  11.40  12.3  14.2
# 8         193.0  11.678756  1.278921   8.5  11.000  12.00  12.6  14.0
# 9           5.0  12.180000  1.013410  10.4  12.400  12.50  12.7  12.9

# %%
print(wine.groupby('type')['quality'].mean())
print(wine.groupby('type')['quality'].median())
# Out:
# type
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64
# type
# red      6.0
# white    6.0
# Name: quality, dtype: float64

# %%
print(wine.groupby('type')['quality'].agg(['mean','std']))
# Out:
#            mean       std
# type
# red    5.636023  0.807569
# white  5.877909  0.885639

# %%
print(wine.groupby('quality')['alcohol','pH'].agg(['mean','sum']))
# Out:
#            alcohol                  pH
#               mean       sum      mean      sum
# quality
# 3        10.215000    306.45  3.257667    97.73
# 4        10.180093   2198.90  3.231620   698.03
# 5         9.837783  21033.18  3.212189  6867.66
# 6        10.587553  30026.30  3.217726  9125.47
# 7        11.386006  12285.50  3.228072  3483.09
# 8        11.678756   2254.00  3.223212   622.08
# 9        12.180000     60.90  3.308000    16.54
# C:\Users\admin\AppData\Local\Temp\ipykernel_1764\3798860028.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(wine.groupby('quality')['alcohol','pH'].agg(['mean','sum']))

# %%
wine.groupby('type').agg({'alcohol':['mean','sum'],'quality':['mean','std']})
# Out:
#          alcohol             quality
#             mean       sum      mean       std
# type
# red    10.422983  16666.35  5.636023  0.807569
# white  10.514267  51498.88  5.877909  0.885639

# %%
quality_count=wine.quality.value_counts()
quality_count=quality_count.sort_index()
print(quality_count)
print(type(quality_count))
# Out:
# 3      30
# 4     216
# 5    2138
# 6    2836
# 7    1079
# 8     193
# 9       5
# Name: quality, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
quality_count.plot(kind='bar')
# Out:
# <Axes: >

# %%
from scipy import stats 
from statsmodels.formula.api import ols, glm

# %%
red_wine_quality=wine.loc[wine['type']=='red','quality']
white_wine_quality=wine.loc[wine['type']=='white','quality']

# %%
print(red_wine_quality)
print(white_wine_quality)
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
stats.ttest_ind(red_wine_quality, white_wine_quality, equal_var=False)
# Out:
# Ttest_indResult(statistic=-10.149363059143164, pvalue=8.168348870049682e-24)

# %%
sns.pairplot(wine[['quality','volatile_acidity','fixed_acidity','residual_sugar','pH','alcohol']])

# %%
formula = 'quality ~ fixed_acidity + volatile_acidity + citric_acid + \
      residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + \
      density + pH + sulphates + alcohol'

# %% [markdown]
# y=s+ax1+bx2+cx3

# %%
regression_result=ols(formula,data=wine).fit()

# %%
regression_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Mon, 24 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:12:31   Log-Likelihood:                -7215.5
# No. Observations:                6497   AIC:                         1.445e+04
# Df Residuals:                    6485   BIC:                         1.454e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
sample=wine[wine.columns.difference(['quality','type'])]
sample1=sample[0:5][:]
sample1
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0      9.4      0.076         0.00   0.9978            7.4
# 1      9.8      0.098         0.00   0.9968            7.8
# 2      9.8      0.092         0.04   0.9970            7.8
# 3      9.8      0.075         0.56   0.9980           11.2
# 4      9.4      0.076         0.00   0.9978            7.4
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 11.0  3.51             1.9       0.56                  34.0
# 1                 25.0  3.20             2.6       0.68                  67.0
# 2                 15.0  3.26             2.3       0.65                  54.0
# 3                 17.0  3.16             1.9       0.58                  60.0
# 4                 11.0  3.51             1.9       0.56                  34.0
#
#    volatile_acidity
# 0              0.70
# 1              0.88
# 2              0.76
# 3              0.28
# 4              0.70

# %%
sample_predict=regression_result.predict(sample1)
print(sample_predict)
# Out:
# 0    4.997607
# 1    4.924993
# 2    5.034663
# 3    5.680333
# 4    4.997607
# dtype: float64

# %%
wine[0:5]['quality']
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
data = {
    "fixed_acidity" : [8.5, 8.1], 
    "volatile_acidity":[0.8, 0.5],
    "citric_acid":[0.3, 0.4], 
    "residual_sugar":[6.1, 5.8], 
    "chlorides":[0.055, 0.04], 
    "free_sulfur_dioxide":[30.0, 31.0], 
    "total_sulfur_dioxide":[98.0,99], 
    "density":[0.996, 0.91], 
    "pH":[3.25, 3.01], 
    "sulphates":[0.4, 0.35],
    "alcohol":[9.0, 0.88]}

# %%
sample2=pd.DataFrame(data, columns=sample1.columns)
sample2
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0     9.00      0.055          0.3    0.996            8.5
# 1     0.88      0.040          0.4    0.910            8.1
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 30.0  3.25             6.1       0.40                  98.0
# 1                 31.0  3.01             5.8       0.35                  99.0
#
#    volatile_acidity
# 0               0.8
# 1               0.5

# %%
sample2_predict=regression_result.predict(sample2)
print(sample2_predict)
# Out:
# 0    4.809094
# 1    7.582129
# dtype: float64

# %%
sns.set_style('dark')
sns.histplot(data=red_wine_quality, kde=True, color='red', label='red wine quality')
sns.histplot(data=white_wine_quality, kde=True, color='blue', label='white wine quality')
plt.title("wine quality")
plt.legend()
plt.show()

# %%
#부분 회귀플롯 시각화
# 독립변수가 2개 이상인 경우 부분 회귀플롯을 사용하여 하나의 독립변수가 종속변수에 미치는 영향을 시각화
# plot_partregress(endog, exog_i, exog_others, data=None, obs_labels=True, ret_coords=False)

# endog : 종속변수 문자열
# exog_i : 분석 대상이되는 독립변수 
# exog_others: 나머지 독립변수
# data: 모든 데이터가 있는 데이터프레임
# obs_label:데이터 라벨링 여부
# ret_coords : 잔차 데이터 반환여부

# %%
import statsmodels.api as sm

others=list(set(wine.columns).difference(set(['quality','fixed_acidity'])))
p, resids=sm.graphics.plot_partregress('quality','fixed_acidity',others, data=wine, 
                                       obs_labels=False,ret_coords=True)
plt.show()
# Out:
# eval_env: 1

# %%
others=list(set(wine.columns).difference(set(['quality','alcohol'])))
p, resids=sm.graphics.plot_partregress('quality','alcohol',others, data=wine, 
                                       obs_labels=False,ret_coords=True)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(6,12))
sm.graphics.plot_partregress_grid(regression_result, fig=fig)
plt.show()
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
