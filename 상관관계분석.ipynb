# %% [markdown]
# # 데이터 상관관계 분석

# %% [markdown]
# # 상관분석과 상관계수
# - 우리는 일상생활에서 “키가 크면 발이 크다”, “교육수준이 높을수록 자녀의 대학 진학률이 높다”등의 이야기를 많이 한다.
# - 이러한 두 개의 변수 ‘키’와 ‘발’, ‘교육수준’과 ‘자녀 대학 진학률’간의 관계가 어떠한 관계를 가지고 있는지 성향을 분석하는 것이 “상관분석”이다.
# - 이를 ‘산포도’ 또는 ‘산점도’라는 그래프로 그리면 직관적으로 두 변수간의 관계를 파악할 수 있다.
# - 예) 어느 집단의 키와 발크기
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import matplotlib

font_location = "c:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)
#plt.rcParams['figure.figsize']=(6,4)
plt.figure(figsize=(6,4))

# %% [markdown]
# # 산포도 그래프 작성(키와 발크기)

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 220, 230, 250, 270, 280, 285]
plt.scatter(height, foot_size)
plt.xlabel('키(Cm)')
plt.ylabel('발크기(mm)')
plt.show()

# %% [markdown]
# # 산포도 그래프 작성(산의 높이에 따른 기온 변화)
# ![image.png](attachment:image.png)

# %%
h = [100, 200, 300, 400, 500, 600, 700, 800, 900]
t = [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
plt.scatter(h, t)
plt.xlabel('산의높이(m)')
plt.ylabel('온도(℃)')
plt.show()

# %%
# 산포도 그래프 작성(상관관계가 없는 데이터)

# %%
# randint(start, end, size) start:시작, end:끝, size:갯수인 임의의 정수를 생성 
random_x = np.random.randint(0, 100, 50) 
random_y = np.random.randint(0, 100, 50)
plt.scatter(random_x, random_y)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.DataFrame({'height':height,'foot_size':foot_size})
print(df.height.corr(df.foot_size))
sns.relplot(x='height',y='foot_size',data=df, height=4)
plt.show()
# Out:
# 0.966126323516351

# %%
df=pd.DataFrame({'h':h,'t':t})
print(df.h.corr(df.t))
sns.relplot(x='h',y='t',data=df)
# Out:
# -0.9879199164035133

# %%
df=pd.DataFrame({'x':random_x, 'y':random_y})
print(df.x.corr(df.y))
sns.relplot(x='x',y='y',data=df)
# Out:
# -0.06754751637331509

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(tips.total_bill.corr(tips.tip))
sns.relplot(x='total_bill', y='tip', data=tips)
# Out:
# 0.6757341092113641

# %%
sns.relplot(x='total_bill', y='tip', col="time",data=tips, hue='time')

# %% [markdown]
# # 상관분석과 상관계수

# %% [markdown]
# - 상관계수
#     - 상관분석에서는 x의 값이 증가함에 따라 y의 값이 증가하는 경우 우리는 “양의 상관관계”를 가지고 있다.
#     - 상관 계수는 서로간의 데이터가 어느 정도의 근접도를 가지고 있는지 표현하는 방법
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 상관계수(기호 : r)
#  - -1≤r≤1 의 값을 가짐
# ![image.png](attachment:image.png)

# %% [markdown]
# - 상관관계 분석식(모집단 전체의 상관계수 공식)
# ![image.png](attachment:image.png)

# %% [markdown]
# - 상관관계 분석식(표본: 일부 샘플들의 상관계수 공식)
# ![image.png](attachment:image.png)

# %%
import math

def correlation(x, y):
    n = len(x)
    vals = range(n)
    x_sum = 0.0
    y_sum = 0.0
    x_sum_pow = 0.0
    y_sum_pow = 0.0
    mul_xy_sum = 0.0
    
    for i in vals:
        mul_xy_sum = mul_xy_sum + float(x[i]) * float(y[i])
        x_sum = x_sum + float(x[i])
        y_sum = y_sum + float(y[i])
        x_sum_pow = x_sum_pow + pow(float(x[i]), 2)
        y_sum_pow = y_sum_pow + pow(float(y[i]), 2)    
    try:
        r = ((n * mul_xy_sum) - (x_sum * y_sum)) / math.sqrt( ((n*x_sum_pow) - pow(x_sum, 2)) * ((n*y_sum_pow) - pow(y_sum, 2)))
    except :
        print("error")
        r = 0.0
    return r

# %%
h = [100, 200, 300, 400, 500, 600, 700, 800, 900]
t = [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
print(h)
print(t)
print('상관분석:',correlation(h, t))
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900]
# [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
# 상관분석: -0.9879199164035135

# %%
print(random_x)
print(random_y)
print('상관분석:',correlation(random_x, random_y))
# Out:
# [77 84 26 77 92 68 39 24 13 77 59 24 39 28 49 57 64 28 21 37 54 12 11 49
#  42 64  5 27 65 50 40 58 76  6 80 80 42 83 55 95 73 81 72 33 41 26 46 55
#  62 87]
# [90 71 64 56 60 64 86 73 97  7 33 70 25 43 44 55 93 76  0 87 33 99 52 57
#  36 94 41 59 83 36 14 56 93 79 47 37  7 29 74 80 69 23 88 40 90 71 27 18
#  84 10]
# 상관분석: -0.06754751637331509

# %% [markdown]
# # Pandas 사용 상관관계분석

# %%
df1=pd.DataFrame({'h':h,'t':t})
print(df.h.corr(df.t))
# Out:
# -0.9879199164035133

# %%
df2=pd.DataFrame({'x':random_x, 'y':random_y})
print(df.x.corr(df.y))
# Out:
# -0.06754751637331509

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 220, 230, 250, 270, 280, 285]
list=[height, foot_size]
df3=pd.DataFrame(list).T
print(df)
corr=df.corr(method='pearson')
print(corr)
# Out:
#      x   y
# 0   77  90
# 1   84  71
# 2   26  64
# 3   77  56
# 4   92  60
# 5   68  64
# 6   39  86
# 7   24  73
# 8   13  97
# 9   77   7
# 10  59  33
# 11  24  70
# 12  39  25
# 13  28  43
# 14  49  44
# 15  57  55
# 16  64  93
# 17  28  76
# 18  21   0
# 19  37  87
# 20  54  33
# 21  12  99
# 22  11  52
# 23  49  57
# 24  42  36
# 25  64  94
# 26   5  41
# 27  27  59
# 28  65  83
# 29  50  36
# 30  40  14
# 31  58  56
# 32  76  93
# 33   6  79
# 34  80  47
# 35  80  37
# 36  42   7
# 37  83  29
# 38  55  74
# 39  95  80
# 40  73  69
# 41  81  23
# 42  72  88
# 43  33  40
# 44  41  90
# 45  26  71
# 46  46  27
# 47  55  18
# 48  62  84
# 49  87  10
#           x         y
# x  1.000000 -0.067548
# y -0.067548  1.000000

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 220, 230, 250, 270, 280, 285]
weight=[25, 30, 38, 35, 40, 45, 55, 68, 70]
list=[height, foot_size,weight]
df4=pd.DataFrame(list).T
df4.columns=['h','f','w']
print(df4)
corr=df4.corr(method='pearson')
print(corr)
# Out:
#      h    f   w
# 0  100  200  25
# 1  120  205  30
# 2  130  210  38
# 3  140  220  35
# 4  150  230  40
# 5  160  250  45
# 6  170  270  55
# 7  180  280  68
# 8  190  285  70
#           h         f         w
# h  1.000000  0.966126  0.952271
# f  0.966126  1.000000  0.969807
# w  0.952271  0.969807  1.000000

# %% [markdown]
# # 상관관계 시각화-heatmap

# %%
df_heatmap = sns.heatmap(corr,  #상관계수 값
                         cbar=True,  #사이드바 표시
                         annot=True,  # 실제값 화면에 표시여부
                         annot_kws={'size': 20},  #글자 크기
                         fmt='.2f',   #소수점 자리수 지징
                         square=True, # 정사각형으로 표시 여부
                         cmap='Blues')  #색장지정, Reds, Greens, Blues

# %%
df_heatmap = sns.heatmap(corr, 
                         cbar=True, 
                         annot=True, 
                         annot_kws={'size': 20}, 
                         cmap='RdYlBu_r', #red, yellow, blue 생상으로 표시
                         vmin=0.95,vmax=1) # 색상 표시 최대값과 최소값

# %%
tips_corr=tips.corr(method='pearson')
print(tips_corr)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df_heatmap = sns.heatmap(tips_corr, 
                         cbar=True, 
                         annot=True, 
                         annot_kws={'size': 12}, 
                         cmap='RdYlBu_r', #red, yellow, blue 생상으로 표시
                         vmin=0.45,vmax=0.9) # 색상 표시 최대값과 최소값

# %%
df_heatmap = sns.heatmap(corr, 
                         cbar=True, 
                         annot=True, 
                         annot_kws={'size': 20}, 
                         cmap='RdYlBu_r', #red, yellow, blue 생상으로 표시
                         vmin=0.95,vmax=1) # 색상 표시 최대값과 최소값

# %%
import numpy as np
fig, ax=plt.subplots(figsize=(7,7))
mask=np.zeros_like(corr, dtype=np.bool) # 삼각형 마스크 만들기 위해 corr 사각형  flase
mask[np.triu_indices_from(mask)]=True #위쪽 삼각형에 True
#mask=np.ones_like(corr, dtype=np.bool) # 삼각형 마스크 만들기 위해 corr 사각형  True
#mask[np.triu_indices_from(mask)]=False # 위쪽 삼각형 삼각형에 False

df_heatmap = sns.heatmap(
    corr, 
    cbar_kws={'shrink':.5}, # 컬라바 크기 절반으로 줄이기
    annot=True, 
    mask=mask, #표시하지 않는 마스크 부분 지정
    linewidth=.5, # 경계면 시선으로 구분하기
    cmap='RdYlBu_r', #red, yellow, blue 색상으로 표시
    vmin=0.92,vmax=1)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11068\1884220429.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(corr, dtype=np.bool) # 삼각형 마스크 만들기 위해 corr 사각형  flase
